# %%
#PYTHON OPERATOR
#"operator are used to perfom opeartions on variables and values."


#ARITHMETIC OPERATOR
#ASSIGNMENT OPERATOR
#COMPARISON OPEARTOR 
#LOGICAL OPEARTOR 
#IDENTIFY OPEARTOR 
#MEMBERSHIP OPERATOR
#BITWISE OPERATOR

# %%
#ARITHMETIC OPERATOR

a=int(input("enter the number"))
b=int(input("enter the number"))
# Out:
# enter the number 33
# enter the number 21

# %%
print(a+b)
# Out:
# 54

# %%
print(a-b)
# Out:
# 12

# %%
print(a*b)
# Out:
# 693

# %%
print(a/b)
# Out:
# 1.5714285714285714

# %%
print(a%b)
# Out:
# 12

# %%
print(a//b)
# Out:
# 1

# %%
print(a**b)
# Out:
# 77409228207421416473589288028833

# %%
print(a//b)
# Out:
# 1

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
#python assignment opeartor
a=5
a=a+3
print(a)
# Out:
# 8

# %%
a+3
print(a)
# Out:
# 8

# %%
a-=3
print(a)
# Out:
# 5

# %%
a*=3
print(a)
# Out:
# 15

# %%
a/=3
print(a)
# Out:
# 5.0

# %%
a%=3
print(a)
# Out:
# 2.0

# %%
#python comparison opearator
a=15
b=15
print(a>b)
# Out:
# False

# %%
print(a==b)
# Out:
# True

# %%
print(a!=b)
# Out:
# False

# %%
print(a>b)
# Out:
# False

# %%
print(a>=b)
# Out:
# True

# %%
print(a<=b)
# Out:
# True

# %%
a=67
b=67
print(a>=b)
# Out:
# True
